# %%
import pandas as pd
import numpy as np
import scimap as sm
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Download data and prepare the anndata object

# %%
# You need the extracted single cell table from the previous session and later also the background-corrected image and masks
## Provide the path to the single-cell feature table from last sessions.
feature_table_path = ["../../exemplar-001/quantification/exemplar-001_backsub--mesmer_cell.csv"]

# create the annData object
adata = sm.pp.mcmicro_to_scimap(feature_table_path)

# %% [markdown]
# # Cluster the data

# %% [markdown]
# ## Leiden

# %%
adata = sm.tl.cluster(adata, method='leiden', resolution=0.4, use_raw=False, log=False) # You can experiment with different resolution parameters and see if that makes sense

# %%
adata.obs['leiden'].value_counts()

# %%
# Generate cluster plots using default settings
sm.pl.cluster_plots(adata, group_by='leiden')

# %%
sm.pl.heatmap(adata, groupBy='leiden', standardScale='column', figsize=(5,4), showPrevalence=True)

# %%
rename_dict = {'Tumor': ['5','1'],
               'Myeloid': ['2'],
               'Treg': ['6'],
               'Vessels': ['4'],
               'Artifacts': ['7'],
                'Immune': ['3','0']}

adata = sm.hl.rename(adata, rename=rename_dict, from_column='leiden', to_column='leiden_phenotype')

# %% [markdown]
# ## You can also experiment with Phenograph if you want
# [Documentation](https://scimap.xyz/Functions/tl/cluster/)

# %% [markdown]
# # Inspect annotations on a dotplot

# %%
sm.pl.spatial_scatterPlot (adata, colorBy = ['leiden_phenotype'],figsize=(3,3), s=0.7, fontsize=5, catCmap='Set1')

# %% [markdown]
# # Inspect annotations on the real images

# %%
image_path = '../../exemplar-001/registration/exemplar-001.ome.tif'
seg_mask = '../../exemplar-001/segmentation/mesmer-exemplar-001_backsub/cell.tif'

# view in napari
sm.pl.image_viewer(image_path=image_path, 
                   adata=adata, 
                   overlay='leiden_phenotype', 
                   point_size=10,
                   point_color='white',
                   seg_mask=seg_mask)

# %% [markdown]
# # Save the adata object

# %%
adata.write_h5ad('../../exemplar-001/cells_annotated.h5ad')
